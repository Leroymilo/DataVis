# %% [markdown]
# ![GPDS Courses Google Colab Banners2.png](data:image/png;base64,...)

# %% [markdown]
# All code in this workbook depend on this cell. Always run this code first.

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the datasets
life_expectancy = pd.read_csv("https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1", low_memory=False)
city_temperature = pd.read_csv("https://www.dropbox.com/s/d56yws7bkn3eeam/city_temperature.csv?raw=1", low_memory=False)

# Some notation
UGLY = "\033[33m╔\033[0m 😖 \033[33;1mUGLY!\033[0m \033[33m═══════════════════════════════\033[0m"
BAD = "\033[35m╔\033[0m 👎 \033[35;1mBAD!\033[0m \033[35m═══════════════════════════════\033[0m"
WRONG = "\033[31m╔\033[0m ❌ \033[31;1mWRONG!\033[0m \033[31m═══════════════════════════════\033[0m"

# %% [markdown]
# # <font color="#B0AD89"><strong>1 ⫶ </strong></font><strong>BASICS OF DATA VISUALIZATION</strong>

# %% [markdown]
# ## <font color="#B0AD89"><strong>1.0 ⫶ </strong></font>Introduction
#
# <img src="https://i.imgur.com/VuwgQ0f.png" width=700 />
#
# <img src="https://i.imgur.com/2MDQQZK.png" width=700 />
#
# <img src="https://i.imgur.com/kfDF8Cb.png" width=700 />
#
# <img src="https://i.imgur.com/eaLDtRd.png" width=700 />

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://i.imgur.com/mwOmjuS.png" width=700 />
#
# <img src="https://i.imgur.com/b03CpcK.png" width=700 />
#
# <img src="https://i.imgur.com/BsQMPA3.png" width=700 />
#
# <img src="https://i.imgur.com/Kqhu8Dz.png" width=700 />

# %% [markdown]
# ## <font color="#B0AD89"><strong>1.1 ⫶ </strong></font>Ugly, bad, and wrong figures

# %% [markdown]
# <img src="https://i.imgur.com/IPO6pVE.png" width=700 />
#
# <img src="https://i.imgur.com/3OKyoVX.png" width=700 />

# %%
# Create the dataframe using pandas
import pandas as pd


# Create the dataframe
df = pd.DataFrame({
    'label': ['A', 'B', 'C', 'D'],
    'amount': [167, 167, 249, 417]
})

# Print the dataframe
print(df)
# Out:
#   label  amount
# 0     A     167
# 1     B     167
# 2     C     249
# 3     D     417

# %%
# Create the plot
plt.figure(figsize=(4, 4))  # Set the plot's width & height
sns.barplot(data=df, x='label', y='amount')  # Create bar plot
plt.show()

# %% [markdown]
# <img src="https://i.imgur.com/2sbbdzl.png" width=700 />

# %%
print(UGLY)

# Create the plot
plt.figure(figsize=(4, 4))
plt.grid(color='yellow', linestyle='-', linewidth=0.5)
sns.barplot(data=df,
            x='label',
            y='amount',
            hue='label',
            palette={'A': 'magenta',   # Manually specify colors
                    'B': 'aqua',
                    'C': 'yellow',
                    'D': 'chartreuse'})
plt.show()
# Out:
# ╔ 😖 UGLY! ═══════════════════════════════

# %% [markdown]
# <img src="https://i.imgur.com/gaMFCuZ.png" width=700 />

# %%
print(BAD)

# Create subplots for each amount
fig, axes = plt.subplots(1, len(df['amount'].unique()), figsize=(4, 4))

for ax, (amount, subset) in zip(axes, df.groupby('amount')):
    sns.barplot(data=subset, x='label', y='amount', ax=ax)

plt.tight_layout()
plt.show()
# Out:
# ╔ 👎 BAD! ═══════════════════════════════

# %% [markdown]
# <img src="https://i.imgur.com/EDMNYcb.png" width=700 />

# %%
print(WRONG)

# Create the plot
plt.figure(figsize=(4, 4))
sns.barplot(x='label', y=df['amount'] - 150, data=df).set(xlabel='', ylabel='')
plt.yticks([])  # This removes y-axis ticks and labels

plt.show()
# Out:
# ╔ ❌ WRONG! ═══════════════════════════════

# %% [markdown]
# <img src="https://i.imgur.com/EDMNYcb.png" width=700 />

# %%
# Create the plot
plt.figure(figsize=(4, 4))  # Set the plot's width & height

# Add light grey grid for y-axis (set zorder=0 to put it behind the bars)
plt.grid(axis='y', color='lightgrey', linestyle='-', zorder=0)

# Create bar plot (set zorder=2 to ensure it's in front)
sns.barplot(data=df, x='label', y='amount', alpha=0.9, zorder=2)

plt.show()

# %% [markdown]
# ### **Practice** <font color="#009BF3"><strong>1.1 ⫶⫶⫶ </strong></font>

# %% [markdown]
# Edit the following code so that the image will be acceptable (not UGLY, not WRONG, not BAD)
#
# ```
# # Create the dataframe
# df = pd.DataFrame({
#     'label': ['X', 'Y', 'Z'],
#     'amount': [15, 25, 20]
# })
#
# plt.figure(figsize=(15, 1.5))
#
# # Create bar plot
# plt.grid(axis='y', color='magenta')
# sns.barplot(data=df,
#             x='label',
#             y=df['amount'] - 10,
#             palette=['yellow', 'cyan', 'yellow'],
#             hue='label',
#             dodge=False)
#
# plt.legend([],[], frameon=False)
# plt.xlabel('')
# plt.ylabel('')
#
# plt.show()
# ```

# %%
# Create the dataframe
df = pd.DataFrame({
    'label': ['X', 'Y', 'Z'],
    'amount': [15, 25, 20]
})

plt.figure(figsize=(5, 5))

# Create bar plot
plt.grid(axis='y', color='lightgrey', linestyle='-')
sns.barplot(data=df,
            x='label',
            y=df['amount'] - 10,
            palette=['yellow', 'red', 'orange'],
            hue='label',
            dodge=False)

plt.legend([],[], frameon=False)
plt.xlabel('Label')
plt.ylabel('Amount')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## <font color="#B0AD89"><strong>1.2 ⫶ </strong></font>Aesthetics and types of data

# %% [markdown]
# <img src="https://i.imgur.com/TeqQzrg.png" width=700 />
#
# <img src="https://i.imgur.com/NC3xyZQ.png" width=700 />
#
# <img src="https://i.imgur.com/3xSkGWf.png" width=700 />
#
# <img src="https://i.imgur.com/Ibnl8q5.png" width=700 />
#
# <img src="https://i.imgur.com/IAgRw8b.png" width=700 />

# %% [markdown]
# ![tab2-1.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://i.imgur.com/Of8Q35x.png" width=700 />

# %%
# Data preparation (equivalent to operations)
japan_temperature = (city_temperature
    .query('Country == "Japan" and Year == 2010')
    .loc[:, ['City', 'Month', 'Day', 'AvgTemperature']]
    .sort_values(['Month', 'Day'])
    .reset_index(drop=True)
)

japan_temperature
# Out:
#          City  Month  Day  AvgTemperature
# 0       Osaka      1    1            38.5
# 1     Sapporo      1    1            31.6
# 2       Tokyo      1    1            42.3
# 3       Osaka      1    2            44.5
# 4     Sapporo      1    2            28.3
# ...       ...    ...  ...             ...
# 1090  Sapporo     12   30            25.3
# 1091    Tokyo     12   30            41.2
# 1092    Osaka     12   31            36.2
# 1093  Sapporo     12   31            28.2
# 1094    Tokyo     12   31            42.5
#
# [1095 rows x 4 columns]

# %% [markdown]
# <img src="https://i.imgur.com/Ze9iDbf.png" width=700 />

# %% [markdown]
# ### **Practice** <font color="#009BF3"><strong>1.2 ⫶⫶⫶ </strong></font>

# %% [markdown]
# Get all rows for the dataset with `Country` is "Canada", `Year` is 2008, `Month` is 12, and `Day` is 25. Arrange it by the order of 'City'. Print the dataset.
#
# ```
# import pandas as pd
# city_temperature = pd.read_csv("https://www.dropbox.com/s/d56yws7bkn3eeam/city_temperature.csv?raw=1", low_memory=False)
#
# canada_temperature = (...)
#
# print(japan_temperature)
# ```

# %%
canada_temp = (city_temperature
	.query("Country==\"Canada\" and Year==2008 and Month==12 and Day==25")
	.loc[:, ['City', 'Month', 'Day', 'AvgTemperature']]
	.sort_values(["City"])
)

canada_temp
# Out:
#               City  Month  Day  AvgTemperature
# 1135223    Calgary     12   25            11.4
# 1142323   Edmonton     12   25            -2.7
# 1149719    Halifax     12   25            41.4
# 1156820   Montreal     12   25            32.6
# 1162533     Ottawa     12   25            31.3
# 1169634     Quebec     12   25            27.5
# 1178899     Regina     12   25            -1.1
# 1188165    Toronto     12   25            32.2
# 1195266  Vancouver     12   25            33.3
# 1202367   Winnipeg     12   25            -4.2

# %% [markdown]
# EXPECTED OUTPUT:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## <font color="#B0AD89"><strong>1.3 ⫶ </strong></font>Scales

# %% [markdown]
# <img src="https://i.imgur.com/vhqh9u1.png" width=700 />
#
#
# <img src="https://i.imgur.com/1vMJPxk.png" width=700 />

# %%
# Import libraries
import pandas as pd

# Data preparation
japan_temperature = (city_temperature
    .query('Country == "Japan" and Year == 2010')                 # filter()
    .assign(Date=lambda x: pd.to_datetime(                        # mutate() with as.Date()
        x[['Year', 'Month', 'Day']].astype(str).agg('-'.join, axis=1)
    ))
    .loc[:, ['City', 'Date', 'AvgTemperature']]                  # select()
    .reset_index(drop=True)
)

print(japan_temperature)
# Out:
#        City       Date  AvgTemperature
# 0     Osaka 2010-01-01            38.5
# 1     Osaka 2010-01-02            44.5
# 2     Osaka 2010-01-03            42.0
# 3     Osaka 2010-01-04            45.7
# 4     Osaka 2010-01-05            41.3
# ...     ...        ...             ...
# 1090  Tokyo 2010-12-27            44.6
# 1091  Tokyo 2010-12-28            47.0
# 1092  Tokyo 2010-12-29            46.7
# 1093  Tokyo 2010-12-30            41.2
# 1094  Tokyo 2010-12-31            42.5
#
# [1095 rows x 3 columns]

# %%
import matplotlib.dates as mdates

plt.figure(figsize=(6, 4))
sns.lineplot(data=japan_temperature,
            x='Date',
            y=japan_temperature['AvgTemperature'].rolling(30).mean(),  # Smoothed temperature
            hue='City')

# Format x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

# Add light grey grid for y-axis
plt.grid(color='lightgrey', linestyle='-')
plt.tight_layout()
plt.show()

# %% [markdown]
# <img src="https://i.imgur.com/CuTIp8T.png" width=700 />
#
#
# <img src="https://i.imgur.com/P76RkQO.png" width=700 />

# %%
# Convert dates to months and create pivot table
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
pivot_data = japan_temperature.pivot_table(
    values='AvgTemperature',
    index='City',
    columns=japan_temperature['Date'].dt.strftime('%b'),
    aggfunc='mean'
)[month_order]

# Create heatmap
plt.figure(figsize=(7, 3))
sns.heatmap(pivot_data,
            cmap='RdBu_r',
            center=50,
            annot=True,  # Show values in cells
            fmt='.1f',   # Round to 1 decimal place
            cbar_kws={'label': 'Temperature (°F)'})

# Remove axis labels
plt.xlabel('')  # Remove x-axis label
plt.ylabel('')  # Remove y-axis label
plt.title('Average Temperature by City and Month in 2010')
plt.tight_layout()
plt.show()

# %% [markdown]
# <img src="https://i.imgur.com/5kMY4yw.png" width=700 />

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read data from URL
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"
life_expectancy = pd.read_csv(url)

# Filter for year 2010
life_expectancy = life_expectancy[
                  (life_expectancy['Year'] == 2010)
]

life_expectancy
# Out:
#                        Country                         Region  Year  \
# 31                 Switzerland                 Rest of Europe  2010
# 35                     Germany                 European Union  2010
# 45                      Belize  Central America and Caribbean  2010
# 46                      Sweden                 European Union  2010
# 50           Brunei Darussalam                           Asia  2010
# ...                        ...                            ...   ...
# 2806                   Austria                 European Union  2010
# 2813          Congo, Dem. Rep.                         Africa  2010
# 2825                    Guyana                  South America  2010
# 2835                     Gabon                         Africa  2010
# 2841  Central African Republic                         Africa  2010
#
#       Infant_deaths  Under_five_deaths  Adult_mortality  Alcohol_consumption  \
# 31              3.9                4.6          56.9105                10.01
# 35              3.5                4.2          77.6040                11.58
# 45             16.2               18.9         181.5840                 6.47
# 46              2.5                3.1          57.4920                 7.38
# 50              7.9                9.7          91.9455                 0.25
# ...             ...                ...              ...                  ...
# 2806            3.6                4.3          74.5020                12.10
# 2813           83.5              113.8         282.5420                 4.02
# 2825           30.6               37.4         216.6485                 5.56
# 2835           41.6               61.7         276.4095                 8.36
# 2841           99.0              145.0         474.0650                 1.96
#
#       Hepatitis_B  Measles   BMI  ...  Incidents_HIV  GDP_per_capita  \
# 31             88       83  25.1  ...           0.06           82027
# 35             88       93  26.3  ...           0.03           37761
# 45             96       91  28.4  ...           0.37            4768
# 46             61       94  25.8  ...           0.08           48370
# 50             96       93  26.4  ...           0.10           33437
# ...           ...      ...   ...  ...            ...             ...
# 2806           86       69  25.4  ...           0.08           43335
# 2813           60       64  21.6  ...           0.53             404
# 2825           95       82  25.8  ...           0.65            4847
# 2835           67       64  24.7  ...           1.90            6864
# 2841           45       64  22.4  ...           1.90             532
#
#       Population_mln  Thinness_ten_nineteen_years  Thinness_five_nine_years  \
# 31              7.82                          0.5                       0.4
# 35             81.78                          1.1                       1.1
# 45              0.32                          3.5                       3.4
# 46              9.38                          1.3                       1.3
# 50              0.39                          5.9                       5.4
# ...              ...                          ...                       ...
# 2806            8.36                          1.7                       1.9
# 2813           64.56                          1.4                       1.2
# 2825            0.75                          5.6                       5.3
# 2835            1.62                          6.5                       6.4
# 2841            4.39                          9.0                       8.9
#
#       Schooling  Economy_status_Developed  Economy_status_Developing  \
# 31         13.3                         1                          0
# 35         13.8                         1                          0
# 45         10.5                         0                          1
# 46         12.3                         1                          0
# 50          8.8                         0                          1
# ...         ...                       ...                        ...
# 2806       11.8                         1                          0
# 2813        5.4                         0                          1
# 2825        8.1                         0                          1
# 2835        7.6                         0                          1
# 2841        3.6                         0                          1
#
#       Life_expectancy  Economy_status
# 31               82.2       Developed
# 35               80.0       Developed
# 45               72.1      Developing
# 46               81.5       Developed
# 50               74.7      Developing
# ...               ...             ...
# 2806             80.6       Developed
# 2813             56.9      Developing
# 2825             68.1      Developing
# 2835             61.4      Developing
# 2841             47.3      Developing
#
# [179 rows x 22 columns]

# %%
plt.figure(figsize=(5, 5))

# Create scatter plot
sns.scatterplot(data=life_expectancy,
               x='GDP_per_capita',
               y='Life_expectancy',
               size='BMI',
               hue='Economy_status',
               alpha=0.75,
               edgecolor='white')

# Add text annotations for specific countries
countries_to_label = ['Japan', 'Haiti', 'New Zealand']
for country in countries_to_label:
   country_data = life_expectancy[life_expectancy['Country'] == country]
   plt.text(x=country_data['GDP_per_capita'].iloc[0],
            y=country_data['Life_expectancy'].iloc[0] + 0.8,
            s=country,
            color='black',
            ha='center')

plt.grid(color='lightgrey', linestyle='-')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Practice** <font color="#009BF3"><strong>1.3 ⫶⫶⫶ </strong></font>

# %% [markdown]
# From the following temperature dataset, complete the following code so the x-axis is the `AvgTemperature`, the y-axis is the `Country`, and the color is `Region`.
#
# ```
# url = "https://www.dropbox.com/s/d56yws7bkn3eeam/city_temperature.csv?raw=1"
# city_temperature = pd.read_csv(url, low_memory=False)
#
# # Filter the data
# city_temperature = city_temperature[
#     (city_temperature['Year'] == 2010) &
#     (city_temperature['Month'] == 2) &
#     (city_temperature['Day'] == 13) &
#     (city_temperature['AvgTemperature'] >= 0) &
#     (city_temperature['Region'].isin(['Africa', 'Asia', 'Europe']))
# ]
#
# # Plotting
# plt.figure(figsize=(6, 15), dpi=300)
# sns.scatterplot(
#     ...,
#     ...,
#     ...,
#     ...,
#     zorder=2
# )
#
# plt.xlabel('Average Temperature (°F)')
# plt.ylabel('Country')
# plt.title('Average Temperature by Country and Region on February 13, 2010')
# plt.grid(color='lightgrey', linestyle='-', zorder=0)
# plt.tight_layout()
#
# plt.show()
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## <font color="#009BF3"><strong>1.4 ⫶ </strong></font>Coordinate systems and axes
#
#
# <img src="https://i.imgur.com/8C4rIRS.png" width=700 />
#
# <img src="https://i.imgur.com/g851IyR.png" width=700 />

# %% [markdown]
# ### <font color="#009BF3"><strong>a ⬝ </strong></font>**Cartesian coordinates**
#
# <img src="https://i.imgur.com/hURF6oi.png" width=700 />
#
# <img src="https://i.imgur.com/h8Pu05a.png" width=700 />
#
# <img src="https://i.imgur.com/20ZF1bl.png" width=700 />

# %%
city_temperature = pd.read_csv(url, low_memory=False)
city_temperature = city_temperature[(city_temperature['City'] == 'Tokyo') & (city_temperature['Year'] == 2010)].copy()
city_temperature['Date'] = pd.to_datetime(city_temperature[['Year', 'Month', 'Day']])

city_temperature
# Out:
#        Region Country State   City  Month  Day  Year  AvgTemperature  \
# 382862   Asia   Japan   NaN  Tokyo      1    1  2010            42.3
# 382863   Asia   Japan   NaN  Tokyo      1    2  2010            44.9
# 382864   Asia   Japan   NaN  Tokyo      1    3  2010            43.7
# 382865   Asia   Japan   NaN  Tokyo      1    4  2010            44.7
# 382866   Asia   Japan   NaN  Tokyo      1    5  2010            44.7
# ...       ...     ...   ...    ...    ...  ...   ...             ...
# 383222   Asia   Japan   NaN  Tokyo     12   27  2010            44.6
# 383223   Asia   Japan   NaN  Tokyo     12   28  2010            47.0
# 383224   Asia   Japan   NaN  Tokyo     12   29  2010            46.7
# 383225   Asia   Japan   NaN  Tokyo     12   30  2010            41.2
# 383226   Asia   Japan   NaN  Tokyo     12   31  2010            42.5
#
#              Date
# 382862 2010-01-01
# 382863 2010-01-02
# 382864 2010-01-03
# 382865 2010-01-04
# 382866 2010-01-05
# ...           ...
# 383222 2010-12-27
# 383223 2010-12-28
# 383224 2010-12-29
# 383225 2010-12-30
# 383226 2010-12-31
#
# [365 rows x 9 columns]

# %%
plot_sizes = [(3, 4), (4, 4), (7, 2)]

for width, height in plot_sizes:
    plt.figure(figsize=(width, height), dpi=300)
    sns.lineplot(data=city_temperature,
            x='Date',
            y=city_temperature['AvgTemperature'].rolling(30).mean()  # Smoothed temperature
            )
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b'))
    plt.xlabel('')
    plt.grid(color='lightgrey', linestyle='-')
    plt.ylabel('Average Temperature (°F)')
    plt.title('Average Temperature in Tokyo (2010)')
    plt.show()

# %% [markdown]
# <img src="https://i.imgur.com/16nt5mN.png" width=700 />

# %%
# Temperature in Fahrenheit
plt.figure(figsize=(4, 4), dpi=300)
sns.lineplot(data=city_temperature,
        x='Date',
        y=city_temperature['AvgTemperature'].rolling(30).mean()  # Smoothed temperature
        )
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b'))
plt.xlabel('')
plt.grid(color='lightgrey', linestyle='-')
plt.ylabel('Average Temperature (°F)')
plt.title('Average Temperature in Tokyo (2010)')
plt.show()

# Temperature converted to Celcius
plt.figure(figsize=(4, 4), dpi=300)
sns.lineplot(data=city_temperature,
        x='Date',
        y=((city_temperature['AvgTemperature']-32)*(5/9)).rolling(30).mean()  # Smoothed temperature
        )
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b'))
plt.xlabel('')
plt.grid(color='lightgrey', linestyle='-')
plt.ylabel('Average Temperature (°C)')
plt.title('Average Temperature in Tokyo (2010)')
plt.show()

# %% [markdown]
# ### <font color="#009BF3"><strong>b ⬝ </strong></font>**Nonlinear scale**

# %% [markdown]
# <img src="https://i.imgur.com/eyVfA9c.png" width=700 />
#
# <img src="https://i.imgur.com/qk6rJiQ.png" width=700 />

# %%
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"

life_expectancy = pd.read_csv(url)
life_expectancy = life_expectancy[life_expectancy['Year'] == 2010]
life_expectancy = life_expectancy[['Country', 'Population_mln']].dropna()

# Making a new column for the ratio of population growth to the world's median
life_expectancy['Population_Ratio'] = life_expectancy['Population_mln'] / life_expectancy['Population_mln'].median()

# Reorder countries by Population_Ratio in descending order
life_expectancy = life_expectancy.sort_values(by='Population_Ratio', ascending=False)
life_expectancy['Country'] = pd.Categorical(life_expectancy['Country'], categories=life_expectancy['Country'], ordered=True)

life_expectancy
# Out:
#                     Country  Population_mln  Population_Ratio
# 484                   China         1337.71        160.782452
# 295                   India         1234.28        148.350962
# 2101          United States          309.33         37.179087
# 1776              Indonesia          241.83         29.066106
# 1033                 Brazil          195.71         23.522837
# ...                     ...             ...               ...
# 1563                  Tonga            0.10          0.012019
# 2585               Kiribati            0.10          0.012019
# 2384  Micronesia, Fed. Sts.            0.10          0.012019
# 683     Antigua and Barbuda            0.09          0.010817
# 2143             Seychelles            0.09          0.010817
#
# [179 rows x 3 columns]

# %%
print(BAD)

# Set plot size
plt.figure(figsize=(8, 6), dpi=300)

# Create the base scatter plot
sns.scatterplot(x='Country', y='Population_Ratio', data=life_expectancy)

# Highlight specific countries
highlight_countries = life_expectancy[life_expectancy['Country'].isin(['Japan', 'China', 'Indonesia'])]

# Add text labels for specific countries
for i, row in highlight_countries.iterrows():
    plt.text(row['Country'], row['Population_Ratio']+5, row['Country'],
             horizontalalignment='left', verticalalignment='bottom', size=12)

# Add segments for specific countries
for i, row in highlight_countries.iterrows():
    plt.plot([row['Country'], row['Country']], [row['Population_Ratio'], row['Population_Ratio'] + 5],
             color='black')

# Customizing the plot
plt.xlabel('Countries, from most to least growth of population')
plt.ylabel('Population Growth / median')

# Remove x-axis text and ticks
plt.xticks([])
plt.tick_params(axis='x', which='both', bottom=False, top=False)

# Remove grid lines along the x-axis
plt.grid(False, axis='x')

plt.show()
# Out:
# ╔ 👎 BAD! ═══════════════════════════════

# %% [markdown]
# <img src="https://i.imgur.com/R4vEK26.png" width=700 />
#
# <img src="https://i.imgur.com/LER2wlS.png" width=700 />

# %%
plt.figure(figsize=(7, 7), dpi=300)

# Create the base scatter plot
sns.scatterplot(x='Country',
                y='Population_Ratio',
                data=life_expectancy,
                color='grey')

# Highlight specific countries
highlight_countries = life_expectancy[life_expectancy['Country'].isin(['Japan', 'China', 'Indonesia'])]

# Add text labels for specific countries
for i, row in highlight_countries.iterrows():
    plt.text(row['Country'],
             row['Population_Ratio'] * 1.3,
             row['Country'],
             horizontalalignment='left',
             verticalalignment='bottom', size=12)

# Add segments for specific countries
for i, row in highlight_countries.iterrows():
    plt.plot([row['Country'], row['Country']],
             [row['Population_Ratio'], row['Population_Ratio'] *1.3],
             color='black')

# Add a horizontal line at the median Population_Ratio
median_ratio = life_expectancy['Population_Ratio'].median()
plt.axhline(y=median_ratio,
            linestyle='dashed',
            color='black')

# Set y-axis to log scale
plt.yscale('log')

# Customize y-axis ticks and labels
plt.yticks(ticks=[10**i for i in range(-2, 4)],
           labels=[f'10^{i}' for i in range(-2, 4)])

# Customizing the plot
plt.xlabel('Countries, from most to least growth of population')
plt.ylabel('Population Growth / median')

# Remove x-axis text and ticks
plt.xticks([])
plt.tick_params(axis='x', which='both', bottom=False, top=False)

# Remove grid lines along the x-axis
plt.grid(False, axis='x')

plt.show()

# %% [markdown]
# ### **Practice** <font color="#009BF3"><strong>1.4 ⫶⫶⫶ </strong></font>

# %% [markdown]
# Plot GDP_per_capita using log scale. Highlight the same countries as the example above.
# Use 10^2 until 10^5 y-axis ticks

# %%
# Dataset Preparation (no change)
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"

life_expectancy = pd.read_csv(url)
life_expectancy = life_expectancy[life_expectancy['Year'] == 2010]
life_expectancy = life_expectancy[['Country', 'GDP_per_capita']].dropna()

# Reorder countries by Population_Ratio in descending order
life_expectancy = life_expectancy.sort_values(by='GDP_per_capita', ascending=False)

life_expectancy
# Out:
#                Country  GDP_per_capita
# 2185        Luxembourg          106544
# 31         Switzerland           82027
# 52              Norway           72427
# 1014             Qatar           63002
# 754          Australia           53543
# ...                ...             ...
# 2343             Niger             443
# 2813  Congo, Dem. Rep.             404
# 934             Malawi             359
# 1195           Burundi             313
# 578            Somalia             296
#
# [179 rows x 2 columns]

# %% [markdown]
# ```
# # Plot
#
# ...
#
# # Customizing the plot
# plt.xlabel('Countries, from most to least GDP per capita (2010)')
# plt.ylabel('GDP per capita in 2010')
#
# # Remove x-axis text and ticks
# plt.xticks([])
# plt.tick_params(axis='x', which='both', bottom=False, top=False)
#
# # Remove grid lines along the x-axis
# plt.grid(False, axis='x')
#
# plt.show()
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## <font color="#009BF3"><strong>1.5 ⫶ </strong></font>Color scales

# %% [markdown]
# <img src="https://i.imgur.com/Sza6Up6.png" width=700 />

# %% [markdown]
# ### <font color="#009BF3"><strong>a ⬝ </strong></font>**Color as a tool to distinguish**

# %% [markdown]
# <img src="https://i.imgur.com/QkDkNK6.png" width=700 />

# %% [markdown]
# #### <font color="#009BF3"><strong>- </strong></font>**Qualitative Palettes**

# %% [markdown]
# <img src="https://i.imgur.com/BbiMhmH.png" width=700 />
#
# <img src="https://i.imgur.com/1jyK3AR.png" width=700 />
#
# <img src="https://i.imgur.com/Y3d4ulN.png" width=700 />

# %%
# URL for the dataset
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"

# Read the dataset
life_expectancy = pd.read_csv(url)

# Filter for the year 2008
life_expectancy = life_expectancy[life_expectancy['Year'] == 2010]

# Display the first 12 rows of the filtered dataset
print(life_expectancy.head(12))
# Out:
#                   Country                         Region  Year  Infant_deaths  \
# 31            Switzerland                 Rest of Europe  2010            3.9
# 35                Germany                 European Union  2010            3.5
# 45                 Belize  Central America and Caribbean  2010           16.2
# 46                 Sweden                 European Union  2010            2.5
# 50      Brunei Darussalam                           Asia  2010            7.9
# 52                 Norway                 Rest of Europe  2010            2.7
# 86          Guinea-Bissau                         Africa  2010           72.6
# 89                Namibia                         Africa  2010           36.8
# 118              Slovenia                 European Union  2010            2.6
# 127                Bhutan                           Asia  2010           34.1
# 151  United Arab Emirates                    Middle East  2010            7.4
# 157                Serbia                 Rest of Europe  2010            6.6
#
#      Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 31                 4.6          56.9105                10.01           88
# 35                 4.2          77.6040                11.58           88
# 45                18.9         181.5840                 6.47           96
# 46                 3.1          57.4920                 7.38           61
# 50                 9.7          91.9455                 0.25           96
# 52                 3.3          64.8620                 6.59           88
# 86               114.5         287.6200                 3.06           83
# 89                49.1         412.4735                 1.40           83
# 118                3.2          86.1920                10.33           88
# 127               42.4         227.3425                 0.23           91
# 151                8.7          74.2960                 1.69           94
# 157                7.6         127.7695                 8.87           89
#
#      Measles   BMI  ...  Incidents_HIV  GDP_per_capita  Population_mln  \
# 31        83  25.1  ...           0.06           82027            7.82
# 35        93  26.3  ...           0.03           37761           81.78
# 45        91  28.4  ...           0.37            4768            0.32
# 46        94  25.8  ...           0.08           48370            9.38
# 50        93  26.4  ...           0.10           33437            0.39
# 52        97  26.4  ...           0.04           72427            4.89
# 86        64  23.0  ...           2.41             586            1.52
# 89        64  23.8  ...           5.85            4147            2.12
# 118       96  26.1  ...           0.02           20613            2.05
# 127       85  23.3  ...           0.16            2235            0.69
# 151       94  28.0  ...           0.13           32535            8.55
# 157       91  25.8  ...           0.02            5206            7.29
#
#      Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 31                           0.5                       0.4       13.3
# 35                           1.1                       1.1       13.8
# 45                           3.5                       3.4       10.5
# 46                           1.3                       1.3       12.3
# 50                           5.9                       5.4        8.8
# 52                           0.7                       0.7       12.7
# 86                           8.0                       7.9        2.6
# 89                           1.4                       1.4        6.2
# 118                          1.6                       1.6       12.1
# 127                         16.6                      17.3        2.3
# 151                          5.1                       4.9        9.9
# 157                          2.2                       2.3       10.4
#
#      Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 31                          1                          0             82.2
# 35                          1                          0             80.0
# 45                          0                          1             72.1
# 46                          1                          0             81.5
# 50                          0                          1             74.7
# 52                          1                          0             81.0
# 86                          0                          1             54.6
# 89                          0                          1             56.7
# 118                         1                          0             79.4
# 127                         0                          1             68.4
# 151                         0                          1             76.3
# 157                         0                          1             74.3
#
#      Economy_status
# 31        Developed
# 35        Developed
# 45       Developing
# 46        Developed
# 50       Developing
# 52        Developed
# 86       Developing
# 89       Developing
# 118       Developed
# 127      Developing
# 151      Developing
# 157      Developing
#
# [12 rows x 22 columns]

# %%
# Select the top 20 countries by 'GDP_per_capita'
top_countries = life_expectancy.nlargest(20, 'GDP_per_capita')

# Set plot size
plt.figure(figsize=(6, 8), dpi=300)

# Create the bar plot
sns.barplot(x='GDP_per_capita',
            y='Country',
            data=top_countries,
            hue='Economy_status',
            palette='Dark2')

# Customize the plot
plt.xlabel('GDP per capita')
plt.ylabel('')
plt.title('Top 20 Countries by GDP per capita (2010)')

# Display the plot
plt.show()

# %% [markdown]
# ### <font color="#009BF3"><strong>b ⬝ </strong></font>**Color to represent data values**

# %% [markdown]
# <img src="https://i.imgur.com/4fyDnm4.png" width=700 />

# %% [markdown]
# #### <font color="#009BF3"><strong>- </strong></font>**Sequential Palettes**
#
# <img src="https://i.imgur.com/gtAdIR7.png" width=700 />
#
# <img src="https://i.imgur.com/yU4J9pX.png" width=700 />
#
# <img src="https://i.imgur.com/gUx6CZJ.png" width=700 />

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define the URL for the life expectancy dataset
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"

# Read the CSV file from the URL
life_expectancy = pd.read_csv(url)

# Filter the data for specific countries
life_expectancy = life_expectancy[life_expectancy['Country'].isin(['Malawi', 'Mozambique', 'Niger', 'Japan'])]

print(life_expectancy.head(12))
# Out:
#         Country  Region  Year  Infant_deaths  Under_five_deaths  \
# 18        Japan    Asia  2005            2.8                3.7
# 91        Japan    Asia  2003            2.9                4.0
# 147      Malawi  Africa  2000          100.5              174.6
# 162      Malawi  Africa  2002           84.6              145.5
# 194       Japan    Asia  2004            2.8                3.9
# 224       Niger  Africa  2009           64.8              130.3
# 312       Niger  Africa  2012           57.0              108.2
# 349      Malawi  Africa  2005           65.0              110.5
# 375  Mozambique  Africa  2007           78.0              118.8
# 383       Niger  Africa  2001           93.7              215.2
# 472  Mozambique  Africa  2014           63.0               88.4
# 529       Japan    Asia  2011            2.3                3.2
#
#      Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 18           68.7680                7.980           83       84  22.6  ...
# 91           70.3060                7.820           83       86  22.5  ...
# 147         570.5510                1.360           79       64  21.7  ...
# 162         591.4675                1.250           64       64  21.9  ...
# 194          68.9285                7.690           83       87  22.6  ...
# 224         270.2910                0.100           71       64  21.5  ...
# 312         261.2055                0.150           71       64  21.6  ...
# 349         528.9610                1.450           93       64  22.1  ...
# 375         402.1220                0.690           75       64  22.1  ...
# 383         290.6955                0.093           72       64  20.9  ...
# 472         344.6300                1.080           79       64  22.6  ...
# 529          64.2585                8.410           83       92  22.7  ...
#
#      Incidents_HIV  GDP_per_capita  Population_mln  \
# 18            0.17           33099          127.77
# 91            0.17           31830          127.72
# 147           9.54             294           11.15
# 162           8.06             271           11.71
# 194           0.17           32515          127.76
# 224           0.12             424           15.84
# 312           0.07             464           17.80
# 349           6.42             289           12.63
# 375           3.50             429           21.67
# 383           0.44             413           11.75
# 472           3.50             569           26.29
# 529           0.17           33011          127.83
#
#      Thinness_ten_nineteen_years  Thinness_five_nine_years  Schooling  \
# 18                           1.7                       1.5       11.2
# 91                           1.7                       1.4       11.0
# 147                          8.0                       7.9        3.0
# 162                          7.7                       7.6        3.2
# 194                          1.7                       1.4       11.1
# 224                         11.0                       1.8        1.4
# 312                          1.3                       1.1        1.6
# 349                          7.4                       7.2        3.4
# 375                          3.8                       3.7        3.0
# 383                         12.7                      12.7        1.1
# 472                          3.6                       3.5        3.4
# 529                          1.9                       1.6       11.8
#
#      Economy_status_Developed  Economy_status_Developing  Life_expectancy  \
# 18                          1                          0             81.9
# 91                          1                          0             81.8
# 147                         0                          1             45.1
# 162                         0                          1             45.5
# 194                         1                          0             82.0
# 224                         0                          1             56.6
# 312                         0                          1             58.8
# 349                         0                          1             47.8
# 375                         0                          1             50.9
# 383                         0                          1             50.6
# 472                         0                          1             56.1
# 529                         1                          0             82.6
#
#      Economy_status
# 18        Developed
# 91        Developed
# 147      Developing
# 162      Developing
# 194       Developed
# 224      Developing
# 312      Developing
# 349      Developing
# 375      Developing
# 383      Developing
# 472      Developing
# 529       Developed
#
# [12 rows x 22 columns]

# %%
# Calculate maximum `Under_five_deaths` for each country
max_val = life_expectancy.groupby('Country')['Under_five_deaths'].max().reset_index()

# Sort the countries by maximum `Under_five_deaths`
sorted_countries = max_val.sort_values(by='Under_five_deaths')['Country'].tolist()

# Create a plot
plt.figure(figsize=(13, 3), dpi=300)
sns.set()
sns.heatmap(life_expectancy.pivot(index='Country', columns='Year', values='Under_five_deaths'),
            cmap='RdPu',
            linewidths=1, linecolor='white')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('')
plt.title('')

plt.show()

# %% [markdown]
# #### <font color="#009BF3"><strong>- </strong></font>**Diverging Palettes**
#
#
# <img src="https://i.imgur.com/6BLkvgA.png" width=700 />
#
# <img src="https://i.imgur.com/hU3LwgY.png" width=700 />
#
# <img src="https://i.imgur.com/R5w4hpb.png" width=700 />

# %%
import calendar

# Define the URL for the temperature dataset
url = "https://www.dropbox.com/s/d56yws7bkn3eeam/city_temperature.csv?raw=1"

# Read the CSV file from the URL
city_temperature = pd.read_csv(url, low_memory=False)

# Filter the data for 2010 and specific cities
city_temperature = city_temperature[(city_temperature['Year'] == 2010) & (city_temperature['City'].isin(['Sydney', 'Tokyo', 'London', 'Paris', 'Beijing', 'Jakarta']))]

# Drop unnecessary columns
city_temperature = city_temperature.drop(['State', 'Country', 'Region'], axis=1)

# Create a new column called "Date"
city_temperature['Date'] = pd.to_datetime(city_temperature[['Year', 'Month', 'Day']].apply(lambda row: f"{row['Year']}-{row['Month']}-{row['Day']}", axis=1))

# Create a dataset with average temperature by month and city
heatmap_data = city_temperature.groupby(['Month', 'City'])['AvgTemperature'].mean().reset_index()

# Specify the order of the month names
heatmap_data['MonthName'] = heatmap_data['Month'].apply(lambda x: calendar.month_name[x])

# Map month names to month abbreviations
month_abbreviations = {name: abbreviation for name, abbreviation in zip(calendar.month_name[1:], calendar.month_abbr[1:])}
heatmap_data['MonthAbbreviation'] = heatmap_data['MonthName'].map(month_abbreviations)

# Sort the cities in the desired order
city_order = ['Sydney', 'London', 'Paris', 'Tokyo', 'Beijing', 'Jakarta']
heatmap_data['City'] = pd.Categorical(heatmap_data['City'], categories=city_order, ordered=True)
# Out:
# <ipython-input-80-c0f7ea440532>:7: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   city_temperature = pd.read_csv(url)

# %%
# Create a plot
plt.figure(figsize=(12, 5), dpi=300)
sns.set()
sns.heatmap(heatmap_data.pivot(index='City', columns='MonthAbbreviation', values='AvgTemperature'),
            cmap='RdYlBu_r',
            linewidths=1,
            linecolor='white', cbar_kws={'shrink': 1}) #"_r" is for reverse

# Set labels and title
plt.xlabel('Month')
plt.ylabel('City')
plt.title('')

plt.show()

# %% [markdown]
# ### <font color="#009BF3"><strong>c ⬝ </strong></font>**Color as a tool to highlight**

# %% [markdown]
# <img src="https://i.imgur.com/1maExSO.png" width=700 />
#
# <img src="https://i.imgur.com/LHgEBAq.png" width=700 />

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://i.imgur.com/hIkB5ON.png" width=700 />

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL for the dataset
url = "https://www.dropbox.com/s/jr72bb2bpcxo725/life_expectancy.csv?raw=1"

# Read the dataset
life_expectancy = pd.read_csv(url)

# Filter for the year 2010
life_expectancy = life_expectancy[life_expectancy['Year'] == 2010]

# Select the top 20 countries by 'GDP_per_capita'
top_countries = life_expectancy.nlargest(25, 'GDP_per_capita')

# Reorder the Country based on 'GDP_per_capita' and create a highlight column
top_countries['Highlight'] = top_countries['Country'].apply(lambda x: 'Highlighted' if x in ['Japan', 'Singapore'] else 'Other')

# Set plot size
plt.figure(figsize=(7, 9), dpi=300)

# Create the bar plot
sns.barplot(x='GDP_per_capita',
            y='Country',
            data=top_countries,
            hue='Highlight',
            palette={'Highlighted': 'blue', 'Other': 'lightgrey'})

# Customize the plot
plt.xlabel('GDP per Capita')
plt.ylabel('')
plt.title('Top 25 Countries by GDP per Capita (2010)')

# Remove the legend
plt.legend([],[], frameon=False)

# Display the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### **Practice** <font color="#009BF3"><strong>1.5 ⫶⫶⫶ </strong></font>

# %% [markdown]
# From the following dataset, we are trying to find the top 50 hottest cities in the world on February 13, 2010. [Use the color palette "Set1"](https://matplotlib.org/stable/users/explain/colors/colormaps.html).

# %%
# URL of the CSV file
url = "https://www.dropbox.com/s/d56yws7bkn3eeam/city_temperature.csv?raw=1"

# Read the CSV file
city_temperature = pd.read_csv(url)

# Filter the data
filtered_data = city_temperature[
    (city_temperature['Year'] == 2010) &
    (city_temperature['Month'] == 2) &
    (city_temperature['Day'] == 13) &
    (city_temperature['AvgTemperature'] >= 0)
].sort_values('AvgTemperature')[['Region','City','AvgTemperature']]

# Get the top 50 rows by AvgTemperature
top_50 = filtered_data.nlargest(50, 'AvgTemperature')

top_50
# Out:
#                                     Region                  City  \
# 170680                              Africa                Niamey
# 212585                              Africa                  Lome
# 152118                              Africa                Maputo
# 19331                               Africa               Cotonou
# 231117                              Africa         Dar Es Salaam
# 102021                              Africa               Abidjan
# 539357                                Asia               Bangkok
# 493027                                Asia             Singapore
# 28597                               Africa                Bangui
# 418902                                Asia          Kuala Lumpur
# 178577                              Africa                 Lagos
# 65687                               Africa            Libreville
# 1297563  South/Central America & Carribean        Rio de Janeiro
# 1411820  South/Central America & Carribean           Panama City
# 37863                               Africa           Brazzaville
# 483761                                Asia                Manila
# 511559                                Asia               Colombo
# 83489                               Africa               Conakry
# 1402575  South/Central America & Carribean               Managua
# 197110                              Africa              Freetown
# 1384045  South/Central America & Carribean        Port au Prince
# 409636                                Asia             Vientiane
# 1343890  South/Central America & Carribean         Santo Domingo
# 437434                                Asia               Rangoon
# 1279755  South/Central America & Carribean            Bridgetown
# 1437981  South/Central America & Carribean             Montvideo
# 145330                              Africa              Lilongwe
# 240413                              Africa               Kampala
# 573303             Australia/South Pacific              Brisbane
# 1447247  South/Central America & Carribean               Caracas
# 1236982  South/Central America & Carribean          Buenos Aires
# 92756                               Africa                Bissau
# 1353155  South/Central America & Carribean             Guayaquil
# 1306828  South/Central America & Carribean             Sao Paulo
# 2905062                      North America  San Juan Puerto Rico
# 355108                                Asia               Jakarta
# 318045                                Asia       Bombay (Mumbai)
# 336577                                Asia      Chennai (Madras)
# 601101             Australia/South Pacific                 Perth
# 1421086  South/Central America & Carribean                  Lima
# 1428715  South/Central America & Carribean            Paramaribo
# 1288297  South/Central America & Carribean              Brasilia
# 1325360  South/Central America & Carribean              San Jose
# 47128                               Africa                 Cairo
# 327311                                Asia              Calcutta
# 1261224  South/Central America & Carribean           Belize City
# 591835             Australia/South Pacific             Melbourne
# 256641                                Asia                 Dhaka
# 1809508                      North America              Honolulu
# 161414                              Africa              Windhoek
#
#          AvgTemperature
# 170680             85.9
# 212585             85.5
# 152118             85.5
# 19331              85.5
# 231117             85.2
# 102021             85.2
# 539357             84.8
# 493027             84.7
# 28597              84.1
# 418902             83.2
# 178577             83.2
# 65687              82.7
# 1297563            82.6
# 1411820            82.2
# 37863              82.0
# 483761             82.0
# 511559             82.0
# 83489              81.6
# 1402575            81.4
# 197110             81.0
# 1384045            81.0
# 409636             81.0
# 1343890            80.8
# 437434             79.8
# 1279755            79.7
# 1437981            79.7
# 145330             79.7
# 240413             79.6
# 573303             79.5
# 1447247            79.4
# 1236982            79.2
# 92756              79.0
# 1353155            78.9
# 1306828            78.8
# 2905062            78.8
# 355108             78.4
# 318045             78.4
# 336577             78.2
# 601101             76.6
# 1421086            76.5
# 1428715            76.4
# 1288297            76.1
# 1325360            75.1
# 47128              74.8
# 327311             74.2
# 1261224            73.9
# 591835             73.6
# 256641             73.1
# 1809508            73.0
# 161414             72.9

# %% [markdown]
# ```
# # Plotting
# plt.figure(figsize=(8, 12), dpi=300)
#
# sns.scatterplot(...,
#                 ...,
#                 ...,
#                 ...,
#                 ...,
#                 s=100,
#                 zorder=2)
# plt.grid(color='lightgrey', linestyle='-', zorder=1)
# plt.title('Top 50 Cities by AvgTemperature on February 13, 2010')
# plt.ylabel('')
# plt.show()
# ```

# %% [markdown]
# ---
